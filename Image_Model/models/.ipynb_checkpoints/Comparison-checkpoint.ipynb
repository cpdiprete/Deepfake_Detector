# %%
import nbimporter
import CNN
import RF
import SVM

# %%
cnnAccuracy = [0.685125, 0.7067083333333334, 0.7282083333333333, 0.746375, 0.764375, 0.782125, 0.7989166666666667, 0.8062083333333333]
rfAccuracy = [0.6945416666666666, 0.7140416666666667, 0.7291666666666666, 0.739, 0.749375, 0.75025, 0.7464166666666666, 0.745875]
svmAccuracy = [0.70025, 0.717625, 0.740625, 0.76375, 0.783, 0.7952083333333333, 0.8019166666666667, 0.8095]

# %% [markdown]
# Comparison of all 3 Models

# %%
import matplotlib.pyplot as plt

retained_variance = [0.60, 0.65, 0.70, 0.75, 0.80, 0.85,0.90,0.95]  

# Plotting the two lines
plt.plot(retained_variance, cnnAccuracy, label='CNN Model', marker='o', color='blue')
plt.plot(retained_variance, rfAccuracy, label='RF Model', marker='s', color='green')
plt.plot(retained_variance, svmAccuracy, label='SVM Model', marker='*', color='red')

# Labels and title
plt.xlabel('Retained Varience')
plt.ylabel('Accuracy')
plt.title('Comparison of Models')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
